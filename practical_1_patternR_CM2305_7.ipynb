# %% [markdown]
# <a href="https://colab.research.google.com/github/NehaMusale11/Pattern-Recognition-/blob/main/practical_1_patternR_CM2305_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-e144517d-192c-4b89-9183-ce891da96794" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e144517d-192c-4b89-9183-ce891da96794">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install nltk

# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from scipy.spatial.distance import euclidean, cityblock
from nltk.metrics.distance import edit_distance

# %%
df = pd.read_excel('Online Retail.xlsx')

print("Customer Dataset")
display(df)
# Out:
# Customer Dataset
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
# ...

# %%
features = ['Quantity', 'UnitPrice']

X = df[features].dropna()

print("Feature Vectors:")
print(X)
# Out:
# Feature Vectors:
#         Quantity  UnitPrice
# 0              6       2.55
# 1              6       3.39
# 2              8       2.75
# 3              6       3.39
# 4              6       3.39
# ...          ...        ...
# 541904        12       0.85
# 541905         6       2.10
# 541906         4       4.15
# 541907         4       4.15
# 541908         3       4.95
#
# [541909 rows x 2 columns]

# %%
cust1 = X.iloc[0].values
cust2 = X.iloc[1].values

print("Customer 1:", cust1)
print("Customer 2:", cust2)
# Out:
# Customer 1: [6.   2.55]
# Customer 2: [6.   3.39]

# %%
eu_dist = euclidean(cust1, cust2)

print("Euclidean Distance =", eu_dist)
# Out:
# Euclidean Distance = 0.8400000000000003

# %%
man_dist = cityblock(cust1, cust2)

print("Manhattan Distance =", man_dist)
# Out:
# Manhattan Distance = 0.8400000000000003

# %%
cos_sim = cosine_similarity([cust1], [cust2])

print("Cosine Similarity =", cos_sim[0][0])
# Out:
# Cosine Similarity = 0.993687984862796

# %%
name1 = df['Description'][0]
name2 = df['Description'][1]

ed_dist = edit_distance(name1, name2)

print("Edit Distance =", ed_dist)
# Out:
# Edit Distance = 23

# %%
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity

# Ensure df is defined
df = pd.read_excel('Online Retail.xlsx')

# Drop rows with NaN CustomerID and convert to int for cleaner indexing
df_cleaned = df.dropna(subset=['CustomerID']).copy() # Explicitly make a copy
df_cleaned['CustomerID'] = df_cleaned['CustomerID'].astype(int)

# Ensure features and X are defined, derived from the cleaned DataFrame
features = ['Quantity', 'UnitPrice']
X = df_cleaned[features].dropna()

print(f"Shape of X before sampling: {X.shape}")

# Sample X to a manageable size for demonstration due to potential memory issues
# A 500k x 500k matrix is too large for typical environments.
# Limiting to the first 1000 rows for example.
X_sample = X.head(1000)

print(f"Shape of X used for similarity matrix (sampled): {X_sample.shape}")

cos_matrix = cosine_similarity(X_sample)

similarity_df = pd.DataFrame(
    cos_matrix,
    index=df_cleaned.loc[X_sample.index, 'CustomerID'],
    columns=df_cleaned.loc[X_sample.index, 'CustomerID']
)

print("Customer Similarity Matrix (Sampled)")
print(f"Shape of similarity_df: {similarity_df.shape}")
display(similarity_df)
# Out:
# Shape of X before sampling: (406829, 2)
# Shape of X used for similarity matrix (sampled): (1000, 2)
# Customer Similarity Matrix (Sampled)
# Shape of similarity_df: (1000, 1000)
# CustomerID     17850     17850     17850     17850     17850     17850  \
# CustomerID
# 17850       1.000000  0.993688  0.997497  0.993688  0.993688  0.611207
# 17850       0.993688  1.000000  0.983267  1.000000  1.000000  0.696136
# 17850       0.997497  0.983267  1.000000  0.983267  0.983267  0.553708
# 17850       0.993688  1.000000  0.983267  1.000000  1.000000  0.696136
# 17850       0.993688  1.000000  0.983267  1.000000  1.000000  0.696136
# ...              ...       ...       ...       ...       ...       ...
# 14729       0.880356  0.928007  0.844610  0.928007  0.928007  0.913485
# 14729       0.880356  0.928007  0.844610  0.928007  0.928007  0.913485
# 14729       0.700143  0.775820  0.647899  0.775820  0.775820  0.993045
# 14729       0.987743  0.999018  0.974233  0.999018  0.999018  0.727255
# ...
